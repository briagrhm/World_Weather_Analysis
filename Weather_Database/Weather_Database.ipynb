# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from citipy import citipy
import time 
from datetime import datetime 
#Import request library 
import requests

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size=2000)
lngs = np.random.uniform(-180,180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(12.298232509578625, 114.45319584970008), (-52.31560490952311, -44.197726820702684), (61.17357338145942, 117.40705243802108), (-60.297374886501395, -23.00801124356653), (71.99249038863266, 27.778643795464177), (15.723043655265982, -21.03569567145277), (8.595255788852114, 138.318684244692), (11.874952154764728, -149.9622489369576), (-43.86560749170336, 88.4290577205017), (-48.093717338407735, 161.83410834705546), (-81.38489306939914, 138.25086841376492), (-34.18744888560401, 22.94302335641578), (22.409882059758672, -124.11989788020912), (41.694267966511575, 11.269234111549565), (-54.572792991611976, 77.91801832323625), (-51.62049334119004, 105.00862236574125), (-48.8094232525799, 106.8522748776304), (8.686312774052084, -160.1324375420023), (-14.630891174781738, 160.22630807229086), (37.28368240634306, -134.80998552647515), (34.77865171032852, -6.402013652105978), (11.372983943661211, -56.31831605726208), (67.23981504489447, -128.16560150996534), (-4.658200888469494, -41.899190323186474), (57.40156676896257, -126.91636042268546), (34.80171082644611, 1.5078601143426624), (-65.58902519403252, -179.33678846373215), (81.04307032275236, 117.41525822561545), (38.15345246848585, -66.12491786911816), (-77.25751868952631, 145.92778264196937), (-81.91469236828328, 50.16669589357039), (-82.10175895009738, -133.24030262572046), (-59.672814764860696, -122.31961007560305), (75.81075753798112, 130.6492341138151), (11.342250642636003, -84.60667754025754), (53.78207918775482, 31.004840759153865), (56.954603916033705, 22.99766016012802), (28.578290167322606, 134.2398912150647), (43.56426731086145, -14.342063952156849), (67.96108268117084, 140.52359791512197), (43.772263432903884, -176.39558512100862), (77.56496100852749, -130.8959606023268), (-52.28696258493439, -134.34967627881718), (-84.77200728871904, -8.668355624663377), (-36.44155412533882, -60.505255088216245), (-74.42474345913027, 67.60600307219778), (32.14782869767991, -95.32042979946058), (61.12230958988812, -31.791888537405214), (46.85649111916675, 117.44346062140693), (38.617334003921684, 121.74807306371468), (8.743424956275874, -35.665062092086515), (-43.990382615709514, 152.729022295402), (-11.174075408131074, 154.77356764803164), (11.832176215478682, -154.56623822977323), (27.610806559540677, 47.21940557953326), (-30.11917504022974, -155.77791584149645), (-27.361243147438515, 121.59610192566748), (65.11833534676816, 169.3744608068435), (42.325691109102564, -63.7561899315336), (47.309276464682796, 155.53803587375353), (87.21247729055341, -0.7904159298040554), (33.500668108406074, 171.0651636201781), (-46.424312367184754, 88.43230114438865), (-12.01216256582586, 113.10424569591987), (-53.47206393570605, -49.17661944535078), (-51.0241795710993, -100.86859355607895), (-14.3243926551295, 5.6039360669756775), (-65.89703998993052, -34.44506724438358), (5.001500346353282, -143.8564283153975), (3.4912266358400075, -142.5369462097184), (32.56928146536622, -169.70566618553008), (36.05840274054809, 18.338806887268106), (80.87083995099465, 115.6011406805743), (-39.35828940700309, -130.85086035310763), (45.052094912472825, -126.83580846968594), (-8.121520667196648, -17.02873535442265), (-67.15301993459815, 41.108644594233), (81.17142404263708, -105.95060199799767), (45.31031956584869, -55.46455320333902), (74.36592111867466, -125.05584777551778), (57.49191961376735, -126.11338131493216), (89.24558735103446, -159.03941540785877), (24.329810868694878, 8.265379467033512), (-57.66373463854112, 113.70733014511518), (33.86592125331394, -155.57864586676143), (-54.154249472134445, 158.20233605304372), (-41.33265926374209, -133.5739380349701), (-14.515186363630647, 135.18512018027684), (21.759290884545265, 155.15567054830188), (-10.822540416635348, 2.9575101995167756), (53.53441881273875, 105.32079140579606), (34.81736848729466, -147.94904967680546), (19.11580169823978, -170.60717667086686), (-3.595857354684995, -116.35819662253743), (-45.325945713998266, -163.6413778467195), (29.451615219562584, -20.643 ...

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
#Create a list for holding cities 
cities = []
#Identify city for each nearest latitude and longitude 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    #If city is unique we will add it to the cities list 
    if city not in cities:
        cities.append(city)
#Print the city count 
len(cities)
# Out:
# 745

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ransang
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | suntar
# Processing Record 4 of Set 1 | chuy
# Processing Record 5 of Set 1 | mehamn
# Processing Record 6 of Set 1 | sal rei
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | tuatapere
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | knysna
# Processing Record 13 of Set 1 | san quintin
# Processing Record 14 of Set 1 | civitavecchia
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | kirakira
# Processing Record 17 of Set 1 | fortuna
# Processing Record 18 of Set 1 | kenitra
# Processing Record 19 of Set 1 | oistins
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | campo maior
# Processing Record 22 of Set 1 | smithers
# Processing Record 23 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | nantucket
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | san carlos
# Processing Record 31 of Set 1 | horki
# Processing Record 32 of Set 1 | tukums
# Processing Record 33 of Set 1 | kushima
# Processing Record 34 of Set 1 | muros
# Processing Record 35 of Set 1 | deputatskiy
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | olavarria
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | jacksonville
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | manzhouli
# Processing Record 44 of Set 1 | dalian
# Processing Record 45 of Set 1 | itarema
# Processing Record 46 of Set 1 | gizo
# Processing Record 47 of Set 1 | doha
# Processing Record 48 of Set 1 | avera
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 2 | liverpool
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | ambulu
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | namibe
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | mouzakion
# City not found. Skipping...
# Processing Record 12 of Set 2 | newport
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | saint-pierre
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | gat
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 2 | katsuura
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | bayanday
# Processing Record 23 of Set 2 | kahului
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | los llanos de aridane
# Processing Record 26 of Set 2 | zyryanka
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | lavrentiya
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | padang
# Processing Record 36 of Set 2 | kuryk
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | boende
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | cherskiy
# Processing Record 41 of Set 2 | henderson
# Processing Record 42 of Set 2 | arcata
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | lapua
# Processing Record 45 of Set 2 | nenjiang
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | jhawarian
# Processing Record 48 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 2 | corinto
# Processing Record 50 of Set 2 | gossaigaon
# Processing Record 1 of Set 3 | victoria
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | kinablangan
# Processing Record 4 of Set 3 | wageningen
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | batemans bay
# Processing Record 7 of Set 3 | savannah bight
# Processing Record 8 of Set 3 | peleduy
# Processing Record 9 of Set 3 | hofn
# Processing Record 10 of Set 3 | lagos
# Processing Record 11 of Set 3 | puerto baquerizo moreno
# Processing Record 12 of Set 3 | oranjemund
# Processing Record 13 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 3 | caravelas
# Processing Record 15 of Set 3 | brae
# Processing Record 16 of Set 3 | koumac
# Processing Record 17 of Set 3 | evensk
# Processing Record 18 of Set 3 | fort nelson
# Processing Record 19 of Set 3 | cape town
# Processing Record 20 of Set 3 | bilibino
# Processing Record 21 of Set 3 | cabo san lucas
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | caracoli
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | ponta do sol
# Processing Record 28 of Set 3 | santa marta
# Processing Record 29 of Set 3 | bathsheba
# Processing Record 30 of Set 3 | valley city
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | ginir
# Processing Record 33 of Set 3 | itaituba
# Processing Record 34 of Set 3 | quibdo
# Processing Record 35 of Set 3 | ewa beach
# Processing Record 36 of Set 3 | ancud
# Processing Record 37 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 3 | mount pleasant
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | mezen
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | poya
# Processing Record 44 of Set 3 | abeche
# Processing Record 45 of Set 3 | sayaxche
# Processing Record 46 of Set 3 | byron bay
# Processing Record 47 of Set 3 | torbay
# Processing Record 48 of Set 3 | codrington
# Processing Record 49 of Set 3 | harnosand
# Processing Record 50 of Set 3 | half moon bay
# Processing Record 1 of Set 4 | pangnirtung
# Processing Record 2 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 4 | bandarbeyla
# Processing Record 4 of Set 4 | umm kaddadah
# Processing Record 5 of Set 4 | plettenberg bay
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 4 | moree
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | dengzhou
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | bambanglipuro
# Processing Record 13 of Set 4 | alofi
# Processing Record 14 of Set 4 | khandwa
# Processing Record 15 of Set 4 | matamoros
# Processing Record 16 of Set 4 | saint-augustin
# Processing Record 17 of Set 4 | pevek
# Processing Record 18 of Set 4 | biltine
# Processing Record 19 of Set 4 | sovetskaya gavan
# Processing Record 20 of Set 4 | ugoofaaru
# Processing Record 21 of Set 4 | labuhan
# Processing Record 22 of Set 4 | clarence town
# Processing Record 23 of Set 4 | itanhem
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | kodiak
# Processing Record 27 of Set 4 | quchan
# Processing Record 28 of Set 4 | bambous virieux
# Processing Record 29 of Set 4 | north bend
# Processing Record 30 of Set 4 | hong gai
# Processing Record 31 of Set 4 | cockburn town
# Processing Record 32 of Set 4 | ust-karsk
# Processing Record 33 of Set 4 | fairbanks
# Processing Record 34 of Set 4 | borjomi
# Processing Record 35 of Set 4 | college
# Processing Record 36 of Set 4 | weimar
# Processing Record 37 of Set 4 | jumla
# Processing Record 38 of Set 4 | killybegs
# Processing Record 39 of Set 4 | lata
# Processing Record 40 of Set 4 | klaksvik
# Processing Record 41 of Set 4 | westport
# Processing Record 42 of Set 4 | phalaborwa
# Processing Record 43 of Set 4 | pisco
# Processing Record 44 of Set 4 | yulara
# Processing Record 45 of Set 4 | kloulklubed
# Processing Record 46 of Set 4 | mbanza-ngungu
# Processing Record 47 of Set 4 | sosua
# Processing Record 48 of Set 4 | lorengau
# Processing Record 49 of Set 4 | khani
# Processing Record 50 of Set 4 | mayo
# Processing Record 1 of Set 5 | tabou
# Processing Record 2 of Set 5 | qandala
# Processing Record 3 of Set 5 | bengkulu
# Processing Record 4 of Set 5 | la asuncion
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | chinhoyi
# Processing Record 7 of Set 5 | kralendijk
# Processing Record 8 of Set 5 | arraial do cabo
# Processing Record 9 of Set 5 | talnakh
# Processing Record 10 of Set 5 | port elizabeth
# Processing Record 11 of Set 5 | mogadishu
# Processing Record 12 of Set 5 | mashhad
# Processing Record 13 of Set 5 | clyde river
# Processing Record 14 of Set 5 | maracacume
# Processing Record 15 of Set 5 | riyadh
# Processing Record 16 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | iqaluit
# Processing Record 19 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 5 | grand gaube
# Processing Record 21 of Set 5 | alugan
# Processing Record 22 of Set 5 | praia da vitoria
# Processing Record 23 of Set 5 | tessalit
# Processing Record 24 of Set 5 | greytown
# Processing Record 25 of Set 5 | santa catarina de tepehuanes
# Processing Record 26 of Set 5 | aswan
# Processing Record 27 of Set 5 | qui nhon
# Processing Record 28 of Set 5 | puerto madero
# Processing Record 29 of Set 5 | uspenka
# Processing Record 30 of Set 5 | chara
# Processing Record 31 of Set 5 | rocha
# Processing Record 32 of Set 5 | yar-sale
# Processing Record 33 of Set 5 | hambantota
# Processing Record 34 of Set 5 | margate
# Processing Record 35 of Set 5 | la playona
# Processing Record 36 of Set 5 | sayyan
# Processing Record 37 of Set 5 | palembang
# Processing Record 38 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 5 | robertson
# Processing Record 40 of Set 5 | bahia honda
# Processing Record 41 of Set 5 | takaka
# Processing Record 42 of Set 5 | san felipe
# Processing Record 43 of Set 5 | coahuayana
# Processing Record 44 of Set 5 | kamiiso
# Processing Record 45 of Set 5 | abrau-dyurso
# Processing Record 46 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 5 | ribeira grande
# Processing Record 48 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 5 | sulangan
# Processing Record 50 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 6 | laguna
# Processing Record 2 of Set 6 | tiznit
# Processing Record 3 of Set 6 | tarko-sale
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | plaster rock
# Processing Record 6 of Set 6 | hebi
# Processing Record 7 of Set 6 | roald
# Processing Record 8 of Set 6 | te anau
# Processing Record 9 of Set 6 | villaviciosa
# Processing Record 10 of Set 6 | acarau
# Processing Record 11 of Set 6 | beringovskiy
# Processing Record 12 of Set 6 | kodinsk
# Processing Record 13 of Set 6 | faanui
# Processing Record 14 of Set 6 | isiro
# Processing Record 15 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 16 of Set 6 | livani
# Processing Record 17 of Set 6 | mkushi
# Processing Record 18 of Set 6 | rundu
# Processing Record 19 of Set 6 | novaya bryan
# Processing Record 20 of Set 6 | havelock
# Processing Record 21 of Set 6 | touros
# Processing Record 22 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 6 | taboga
# Processing Record 24 of Set 6 | kununurra
# Processing Record 25 of Set 6 | cervo
# Processing Record 26 of Set 6 | dubti
# Processing Record 27 of Set 6 | bredasdorp
# Processing Record 28 of Set 6 | pacasmayo
# Processing Record 29 of Set 6 | maniitsoq
# Processing Record 30 of Set 6 | shonguy
# Processing Record 31 of Set 6 | walvis bay
# Processing Record 32 of Set 6 | ballina
# Processing Record 33 of Set 6 | lompoc
# Processing Record 34 of Set 6 | fare
# Processing Record 35 of Set 6 | shu
# Processing Record 36 of Set 6 | kumluca
# Processing Record 37 of Set 6 | isabela
# Processing Record 38 of Set 6 | olafsvik
# Processing Record 39 of Set 6 | calama
# Processing Record 40 of Set 6 | yining
# Processing Record 41 of Set 6 | east london
# Processing Record 42 of Set 6 | constitucion
# Processing Record 43 of Set 6 | formiga
# Processing Record 44 of Set 6 | mount isa
# Processing Record 45 of Set 6 | banepa
# Processing Record 46 of Set 6 | buraydah
# Processing Record 47 of Set 6 | szczytno
# Processing Record 48 of Set 6 | haines junction
# Processing Record 49 of Set 6 | trairi
# Processing Record 50 of Set 6 | nha trang
# Processing Record 1 of Set 7 | marrakesh
# Processing Record 2 of Set 7 | boa vista
# Processing Record 3 of Set 7 | abu dhabi
# Processing Record 4 of Set 7 | anadyr
# Processing Record 5 of Set 7 | ixcaquixtla
# City not found. Skipping...
# Processing Record 6 of Set 7 | lesozavodsk
# Processing Record 7 of Set 7 | dillon
# Processing Record 8 of Set 7 | kozhva
# Processing Record 9 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 7 | mana
# Processing Record 11 of Set 7 | heze
# Processing Record 12 of Set 7 | kaitangata
# Processing Record 13 of Set 7 | coffs harbour
# Processing Record 14 of Set 7 | okhotsk
# Processing Record 15 of Set 7 | aksu
# Processing Record 16 of Set 7 | leiyang
# Processing Record 17 of Set 7 | sao jose da coroa grande
# Processing Record 18 of Set 7 | vestmannaeyjar
# Processing Record 19 of Set 7 | brainerd
# Processing Record 20 of Set 7 | ikungi
# Processing Record 21 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 7 | sao joao da barra
# Processing Record 23 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 24 of Set 7 | solton
# Processing Record 25 of Set 7 | tanete
# Processing Record 26 of Set 7 | foix
# Processing Record 27 of Set 7 | abashiri
# Processing Record 28 of Set 7 | kabanjahe
# Processing Record 29 of Set 7 | palmer
# Processing Record 30 of Set 7 | lasa
# Processing Record 31 of Set 7 | saint george
# Processing Record 32 of Set 7 | adrar
# Processing Record 33 of Set 7 | shingu
# Processing Record 34 of Set 7 | chaoyang
# Processing Record 35 of Set 7 | wilmington
# Processing Record 36 of Set 7 | korla
# Processing Record 37 of Set 7 | jiangyou
# Processing Record 38 of Set 7 | collie
# Processing Record 39 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 7 | san policarpo
# Processing Record 41 of Set 7 | acapulco
# Processing Record 42 of Set 7 | kayerkan
# Processing Record 43 of Set 7 | mildura
# Processing Record 44 of Set 7 | nuuk
# Processing Record 45 of Set 7 | antofagasta
# Processing Record 46 of Set 7 | huanren
# Processing Record 47 of Set 7 | saldanha
# Processing Record 48 of Set 7 | qena
# Processing Record 49 of Set 7 | kumylzhenskaya
# Processing Record 50 of Set 7 | port-cartier
# Processing Record 1 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 8 | cumaral
# Processing Record 3 of Set 8 | biskamzha
# Processing Record 4 of Set 8 | samarai
# Processing Record 5 of Set 8 | ramsey
# Processing Record 6 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 8 | shemgang
# Processing Record 8 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 8 | kamaishi
# Processing Record 10 of Set 8 | yarada
# Processing Record 11 of Set 8 | lanigan
# Processing Record 12 of Set 8 | san ramon
# Processing Record 13 of Set 8 | henties bay
# Processing Record 14 of Set 8 | kulhudhuffushi
# Processing Record 15 of Set 8 | dubbo
# Processing Record 16 of Set 8 | erenhot
# Processing Record 17 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 8 | leningradskiy
# Processing Record 19 of Set 8 | kupang
# Processing Record 20 of Set 8 | markova
# Processing Record 21 of Set 8 | senador guiomard
# Processing Record 22 of Set 8 | urusha
# Processing Record 23 of Set 8 | el tigre
# Processing Record 24 of Set 8 | vao
# Processing Record 25 of Set 8 | konya
# Processing Record 26 of Set 8 | vardo
# Processing Record 27 of Set 8 | bafq
# Processing Record 28 of Set 8 | geraldton
# Processing Record 29 of Set 8 | taltal
# Processing Record 30 of Set 8 | kruisfontein
# Processing Record 31 of Set 8 | ljungby
# Processing Record 32 of Set 8 | aripuana
# Processing Record 33 of Set 8 | chokurdakh
# Processing Record 34 of Set 8 | bonthe
# Processing Record 35 of Set 8 | samarinda
# Processing Record 36 of Set 8 | rio grande
# Processing Record 37 of Set 8 | pafos
# Processing Record 38 of Set 8 | seydi
# Processing Record 39 of Set 8 | rudbar
# Processing Record 40 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 8 | oktyabrskoye
# Processing Record 42 of Set 8 | ndago
# Processing Record 43 of Set 8 | carupano
# Processing Record 44 of Set 8 | vila do maio
# Processing Record 45 of Set 8 | flinders
# Processing Record 46 of Set 8 | keti bandar
# Processing Record 47 of Set 8 | hamilton
# Processing Record 48 of Set 8 | qaqortoq
# Processing Record 49 of Set 8 | cam ranh
# Processing Record 50 of Set 8 | guarapari
# Processing Record 1 of Set 9 | labrea
# Processing Record 2 of Set 9 | hurghada
# Processing Record 3 of Set 9 | honiara
# Processing Record 4 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 9 | sept-iles
# Processing Record 6 of Set 9 | traverse city
# City not found. Skipping...
# Processing Record 7 of Set 9 | gigmoto
# Processing Record 8 of Set 9 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 9 of Set 9 | sitka
# Processing Record 10 of Set 9 | moissala
# Processing Record 11 of Set 9 | wattegama
# Processing Record 12 of Set 9 | ndele
# Processing Record 13 of Set 9 | winnemucca
# Processing Record 14 of Set 9 | road town
# Processing Record 15 of Set 9 | candelaria
# Processing Record 16 of Set 9 | kamenka
# Processing Record 17 of Set 9 | severomuysk
# Processing Record 18 of Set 9 | artigas
# Processing Record 19 of Set 9 | opuwo
# Processing Record 20 of Set 9 | kazachinskoye
# Processing Record 21 of Set 9 | havoysund
# Processing Record 22 of Set 9 | kargasok
# Processing Record 23 of Set 9 | matoury
# Processing Record 24 of Set 9 | el alto
# Processing Record 25 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 9 | kostyantynivka
# Processing Record 27 of Set 9 | manaus
# Processing Record 28 of Set 9 | vitimskiy
# City not found. Skipping...
# Processing Record 29 of Set 9 | jaicos
# Processing Record 30 of Set 9 | carutapera
# Processing Record 31 of Set 9 | malaya purga
# Processing Record 32 of Set 9 | baker city
# Processing Record 33 of Set 9 | itiuba
# Processing Record 34 of Set 9 | kalmunai
# Processing Record 35 of Set 9 | bansgaon
# Processing Record 36 of Set 9 | san patricio
# Processing Record 37 of Set 9 | businga
# Processing Record 38 of Set 9 | chapais
# Processing Record 39 of Set 9 | puerto escondido
# Processing Record 40 of Set 9 | port hardy
# Processing Record 41 of Set 9 | wonthaggi
# Processing Record 42 of Set 9 | atambua
# Processing Record 43 of Set 9 | taoudenni
# Processing Record 44 of Set 9 | wallacetown
# Processing Record 45 of Set 9 | tema
# Processing Record 46 of Set 9 | tra vinh
# Processing Record 47 of Set 9 | kremenchuk
# Processing Record 48 of Set 9 | benton harbor
# Processing Record 49 of Set 9 | san luis
# Processing Record 50 of Set 9 | pacific grove
# Processing Record 1 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 10 | rogova
# Processing Record 3 of Set 10 | price
# Processing Record 4 of Set 10 | mitsamiouli
# Processing Record 5 of Set 10 | mustasaari
# Processing Record 6 of Set 10 | daru
# Processing Record 7 of Set 10 | hinton
# Processing Record 8 of Set 10 | san andres
# Processing Record 9 of Set 10 | norfolk
# Processing Record 10 of Set 10 | sisimiut
# Processing Record 11 of Set 10 | urengoy
# Processing Record 12 of Set 10 | douentza
# Processing Record 13 of Set 10 | caldwell
# Processing Record 14 of Set 10 | idritsa
# Processing Record 15 of Set 10 | barda
# Processing Record 16 of Set 10 | kavaratti
# Processing Record 17 of Set 10 | udachnyy
# Processing Record 18 of Set 10 | port macquarie
# Processing Record 19 of Set 10 | ahipara
# Processing Record 20 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 10 | catuday
# Processing Record 22 of Set 10 | san cristobal
# Processing Record 23 of Set 10 | lashio
# Processing Record 24 of Set 10 | salekhard
# Processing Record 25 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 10 | necochea
# Processing Record 27 of Set 10 | hay river
# Processing Record 28 of Set 10 | khandyga
# Processing Record 29 of Set 10 | camacha
# Processing Record 30 of Set 10 | nanortalik
# Processing Record 31 of Set 10 | chicama
# Processing Record 32 of Set 10 | warwick
# Processing Record 33 of Set 10 | arona
# Processing Record 34 of Set 10 | las matas de farfan
# Processing Record 35 of Set 10 | newburyport
# Processing Record 36 of Set 10 | birjand
# Processing Record 37 of Set 10 | helena
# Processing Record 38 of Set 10 | owosso
# Processing Record 39 of Set 10 | verkhoyansk
# Processing Record 40 of Set 10 | lengshuitan
# Processing Record 41 of Set 10 | khandbari
# Processing Record 42 of Set 10 | salalah
# Processing Record 43 of Set 10 | atar
# Processing Record 44 of Set 10 | port keats
# Processing Record 45 of Set 10 | guerrero negro
# Processing Record 46 of Set 10 | nome
# Processing Record 47 of Set 10 | maralal
# Processing Record 48 of Set 10 | kimbe
# Processing Record 49 of Set 10 | nelson bay
# Processing Record 50 of Set 10 | ilulissat
# Processing Record 1 of Set 11 | batelov
# Processing Record 2 of Set 11 | rabo de peixe
# Processing Record 3 of Set 11 | isangel
# Processing Record 4 of Set 11 | tilichiki
# Processing Record 5 of Set 11 | almeirim
# Processing Record 6 of Set 11 | la cumbre
# Processing Record 7 of Set 11 | ossora
# Processing Record 8 of Set 11 | hefei
# Processing Record 9 of Set 11 | muisne
# Processing Record 10 of Set 11 | rosarito
# Processing Record 11 of Set 11 | bilma
# Processing Record 12 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 11 | otradnoye
# Processing Record 14 of Set 11 | santa cruz
# Processing Record 15 of Set 11 | moose factory
# Processing Record 16 of Set 11 | camana
# Processing Record 17 of Set 11 | sungairaya
# Processing Record 18 of Set 11 | murray bridge
# Processing Record 19 of Set 11 | lucera
# Processing Record 20 of Set 11 | minab
# Processing Record 21 of Set 11 | santiago del estero
# Processing Record 22 of Set 11 | morrope
# Processing Record 23 of Set 11 | nhulunbuy
# Processing Record 24 of Set 11 | kayseri
# Processing Record 25 of Set 11 | sompeta
# Processing Record 26 of Set 11 | hasaki
# Processing Record 27 of Set 11 | tunghsiao
# City not found. Skipping...
# Processing Record 28 of Set 11 | chernyshevskiy
# Processing Record 29 of Set 11 | raudeberg
# Processing Record 30 of Set 11 | tofield
# Processing Record 31 of Set 11 | mount gambier
# Processing Record 32 of Set 11 | najran
# Processing Record 33 of Set 11 | filadelfia
# Processing Record 34 of Set 11 | hualmay
# Processing Record 35 of Set 11 | kungurtug
# Processing Record 36 of Set 11 | biak
# Processing Record 37 of Set 11 | kinwat
# Processing Record 38 of Set 11 | narsaq
# Processing Record 39 of Set 11 | nouadhibou
# Processing Record 40 of Set 11 | hemet
# Processing Record 41 of Set 11 | wagar
# Processing Record 42 of Set 11 | rio branco
# Processing Record 43 of Set 11 | saint-leu
# Processing Record 44 of Set 11 | stranraer
# Processing Record 45 of Set 11 | bagn
# Processing Record 46 of Set 11 | falaleu
# City not found. Skipping...
# Processing Record 47 of Set 11 | augusto correa
# Processing Record 48 of Set 11 | bubaque
# Processing Record 49 of Set 11 | pathein
# Processing Record 50 of Set 11 | zhigansk
# Processing Record 1 of Set 12 | poum
# Processing Record 2 of Set 12 | presidente dutra
# Processing Record 3 of Set 12 | perote
# Processing Record 4 of Set 12 | nicoya
# Processing Record 5 of Set 12 | marawi
# Processing Record 6 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 12 | zhangjiakou
# Processing Record 8 of Set 12 | urumqi
# Processing Record 9 of Set 12 | turukhansk
# Processing Record 10 of Set 12 | okato
# Processing Record 11 of Set 12 | zabid
# Processing Record 12 of Set 12 | hingatungan
# Processing Record 13 of Set 12 | balkanabat
# Processing Record 14 of Set 12 | spencer
# Processing Record 15 of Set 12 | aykhal
# Processing Record 16 of Set 12 | roebourne
# Processing Record 17 of Set 12 | neuquen
# Processing Record 18 of Set 12 | miraflores
# Processing Record 19 of Set 12 | virginia beach
# Processing Record 20 of Set 12 | chala
# Processing Record 21 of Set 12 | priargunsk
# Processing Record 22 of Set 12 | teeli
# Processing Record 23 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 12 | bayshore gardens
# Processing Record 25 of Set 12 | tulagi
# Processing Record 26 of Set 12 | evanston
# Processing Record 27 of Set 12 | gopalpur
# Processing Record 28 of Set 12 | misratah
# Processing Record 29 of Set 12 | beira
# Processing Record 30 of Set 12 | marzuq
# Processing Record 31 of Set 12 | uyemskiy
# Processing Record 32 of Set 12 | broken hill
# Processing Record 33 of Set 12 | kostomuksha
# Processing Record 34 of Set 12 | kudahuvadhoo
# Processing Record 35 of Set 12 | freeport
# Processing Record 36 of Set 12 | saint-joseph
# Processing Record 37 of Set 12 | saint anthony
# Processing Record 38 of Set 12 | fort-shevchenko
# Processing Record 39 of Set 12 | baykit
# Processing Record 40 of Set 12 | maloh
# Processing Record 41 of Set 12 | saint-georges
# Processing Record 42 of Set 12 | romitan
# Processing Record 43 of Set 12 | richards bay
# Processing Record 44 of Set 12 | pacifica
# Processing Record 45 of Set 12 | mardin
# Processing Record 46 of Set 12 | sorland
# Processing Record 47 of Set 12 | roma
# Processing Record 48 of Set 12 | aberdeen
# Processing Record 49 of Set 12 | la ronge
# Processing Record 50 of Set 12 | gualaquiza
# Processing Record 1 of Set 13 | torquay
# Processing Record 2 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 13 | zhigalovo
# Processing Record 4 of Set 13 | tautira
# Processing Record 5 of Set 13 | pushkino
# Processing Record 6 of Set 13 | arroyo
# Processing Record 7 of Set 13 | nortelandia
# Processing Record 8 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 13 | reconquista
# Processing Record 10 of Set 13 | selkirk
# Processing Record 11 of Set 13 | rindal
# Processing Record 12 of Set 13 | inongo
# Processing Record 13 of Set 13 | ostrovnoy
# Processing Record 14 of Set 13 | baturaja
# Processing Record 15 of Set 13 | ongandjera
# Processing Record 16 of Set 13 | dzerzhinsk
# Processing Record 17 of Set 13 | jizan
# Processing Record 18 of Set 13 | kalengwa
# Processing Record 19 of Set 13 | damietta
# Processing Record 20 of Set 13 | yenagoa
# Processing Record 21 of Set 13 | kangaatsiaq
# Processing Record 22 of Set 13 | cap malheureux
# Processing Record 23 of Set 13 | sangar
# Processing Record 24 of Set 13 | katsina
# Processing Record 25 of Set 13 | caconda
# Processing Record 26 of Set 13 | harper
# Processing Record 27 of Set 13 | oussouye
# Processing Record 28 of Set 13 | egvekinot
# Processing Record 29 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 13 | san carlos de bariloche
# Processing Record 31 of Set 13 | sayanskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | prescott
# Processing Record 33 of Set 13 | ushtobe
# Processing Record 34 of Set 13 | cape canaveral
# Processing Record 35 of Set 13 | anito
# Processing Record 36 of Set 13 | the pas
# Processing Record 37 of Set 13 | havre-saint-pierre
# Processing Record 38 of Set 13 | kandrian
# Processing Record 39 of Set 13 | aleksandrov gay
# Processing Record 40 of Set 13 | ambositra
# Processing Record 41 of Set 13 | tateyama
# Processing Record 42 of Set 13 | chimore
# Processing Record 43 of Set 13 | port hedland
# Processing Record 44 of Set 13 | lundazi
# Processing Record 45 of Set 13 | shakiso
# Processing Record 46 of Set 13 | bratsk
# Processing Record 47 of Set 13 | cartagena
# Processing Record 48 of Set 13 | wamba
# Processing Record 49 of Set 13 | rumonge
# Processing Record 50 of Set 13 | gamba
# Processing Record 1 of Set 14 | scottsbluff
# Processing Record 2 of Set 14 | eyemouth
# Processing Record 3 of Set 14 | coihaique
# Processing Record 4 of Set 14 | mayumba
# Processing Record 5 of Set 14 | agadez
# Processing Record 6 of Set 14 | mangan
# Processing Record 7 of Set 14 | dingle
# Processing Record 8 of Set 14 | san buenaventura
# Processing Record 9 of Set 14 | debre birhan
# Processing Record 10 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 11 of Set 14 | pangai
# Processing Record 12 of Set 14 | champerico
# Processing Record 13 of Set 14 | sijunjung
# Processing Record 14 of Set 14 | high rock
# Processing Record 15 of Set 14 | lazaro cardenas
# Processing Record 16 of Set 14 | batagay-alyta
# Processing Record 17 of Set 14 | great bend
# Processing Record 18 of Set 14 | pimentel
# Processing Record 19 of Set 14 | sherlovaya gora
# Processing Record 20 of Set 14 | pochutla
# Processing Record 21 of Set 14 | asau
# Processing Record 22 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 23 of Set 14 | bo phloi
# Processing Record 24 of Set 14 | anzio
# Processing Record 25 of Set 14 | bayji
# Processing Record 26 of Set 14 | omaruru
# Processing Record 27 of Set 14 | hobyo
# Processing Record 28 of Set 14 | ayios matthaios
# City not found. Skipping...
# Processing Record 29 of Set 14 | colares
# Processing Record 30 of Set 14 | karangampel
# Processing Record 31 of Set 14 | satipo
# Processing Record 32 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 14 | kaili
# Processing Record 34 of Set 14 | kaohsiung
# Processing Record 35 of Set 14 | maceio
# Processing Record 36 of Set 14 | kedrovyy
# Processing Record 37 of Set 14 | tahta
# Processing Record 38 of Set 14 | ikalamavony
# Processing Record 39 of Set 14 | penzance
# Processing Record 40 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 42 of Set 14 | kaura namoda
# Processing Record 43 of Set 14 | kirovskiy
# Processing Record 44 of Set 14 | somerset
# Processing Record 45 of Set 14 | bay roberts
# Processing Record 46 of Set 14 | gravdal
# Processing Record 47 of Set 14 | krasnoselkup
# Processing Record 48 of Set 14 | curumani
# Processing Record 49 of Set 14 | friendly
# Processing Record 50 of Set 14 | mariani
# Processing Record 1 of Set 15 | hami
# Processing Record 2 of Set 15 | nemuro
# Processing Record 3 of Set 15 | de-kastri
# Processing Record 4 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 15 | artyshta
# Processing Record 6 of Set 15 | luanda
# Processing Record 7 of Set 15 | lunino
# Processing Record 8 of Set 15 | bafoulabe
# Processing Record 9 of Set 15 | goderich
# Processing Record 10 of Set 15 | tawang
# Processing Record 11 of Set 15 | yeniseysk
# Processing Record 12 of Set 15 | tamsalu
# Processing Record 13 of Set 15 | jau
# Processing Record 14 of Set 15 | sochi
# Processing Record 15 of Set 15 | bagdarin
# Processing Record 16 of Set 15 | bacolod
# Processing Record 17 of Set 15 | zlitan
# Processing Record 18 of Set 15 | flin flon
# Processing Record 19 of Set 15 | sola
# Processing Record 20 of Set 15 | nyurba
# Processing Record 21 of Set 15 | maldonado
# Processing Record 22 of Set 15 | karlstad
# Processing Record 23 of Set 15 | pierre
# Processing Record 24 of Set 15 | labuan
# Processing Record 25 of Set 15 | yerbogachen
# Processing Record 26 of Set 15 | prince rupert
# Processing Record 27 of Set 15 | kerouane
# Processing Record 28 of Set 15 | pringsewu
# Processing Record 29 of Set 15 | terny
# Processing Record 30 of Set 15 | inhambane
# Processing Record 31 of Set 15 | keetmanshoop
# Processing Record 32 of Set 15 | kizema
# Processing Record 33 of Set 15 | faya
# Processing Record 34 of Set 15 | along
# Processing Record 35 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 15 | hereford
# Processing Record 37 of Set 15 | bam
# Processing Record 38 of Set 15 | coquimbo
# Processing Record 39 of Set 15 | kyakhta
# Processing Record 40 of Set 15 | rizhao
# Processing Record 41 of Set 15 | presidencia roque saenz pena
# Processing Record 42 of Set 15 | minas
# Processing Record 43 of Set 15 | peniche
# Processing Record 44 of Set 15 | vysokogornyy
# Processing Record 45 of Set 15 | prattville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 688

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ransang   8.9603  117.5828     77.72        77         100
# 1  Mar Del Plata -38.0023  -57.5575     72.95        87          75
# 2         Suntar  62.1444  117.6319     -4.61        96         100
# 3           Chuy -33.6971  -53.4616     70.56        87         100
# 4         Mehamn  71.0357   27.8492     24.71        93          75
# 5        Sal Rei  16.1833  -22.9167     71.80        64          75
# 6          Airai  -8.9266  125.4092     61.21        96         100
# 7           Hilo  19.7297 -155.0900     83.28        75           0
# 8      Busselton -33.6500  115.3333     61.86        80           0
# 9      Tuatapere -46.1333  167.6833     63.66        97          87
#
#    Wind Speed Country                 Date Current Description
# 0        3.53      PH  2023-02-02 19:01:35     overcast clouds
# 1       14.00      AR  2023-02-02 19:01:36       moderate rain
# 2        5.32      RU  2023-02-02 19:01:36     overcast clouds
# 3       15.43      UY  2023-02-02 19:01:36          light rain
# 4        3.44      NO  2023-02-02 19:01:37          light snow
# 5       19.57      CV  2023-02-02 19:01:37       broken clouds
# 6        2.95      TL  2023-02-02 19:01:38     overcast clouds
# 7        5.75      US  2023-02-02 18:57:36           clear sky
# 8       15.79      AU  2023-02-02 19:01:38           clear sky
# 9        3.20      NZ  2023-02-02 19:01:39     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ransang      PH   8.9603  117.5828     77.72        77         100
# 1  Mar Del Plata      AR -38.0023  -57.5575     72.95        87          75
# 2         Suntar      RU  62.1444  117.6319     -4.61        96         100
# 3           Chuy      UY -33.6971  -53.4616     70.56        87         100
# 4         Mehamn      NO  71.0357   27.8492     24.71        93          75
# 5        Sal Rei      CV  16.1833  -22.9167     71.80        64          75
# 6          Airai      TL  -8.9266  125.4092     61.21        96         100
# 7           Hilo      US  19.7297 -155.0900     83.28        75           0
# 8      Busselton      AU -33.6500  115.3333     61.86        80           0
# 9      Tuatapere      NZ -46.1333  167.6833     63.66        97          87
#
#    Wind Speed Current Description
# 0        3.53     overcast clouds
# 1       14.00       moderate rain
# 2        5.32     overcast clouds
# 3       15.43          light rain
# 4        3.44          light snow
# 5       19.57       broken clouds
# 6        2.95     overcast clouds
# 7        5.75           clear sky
# 8       15.79           clear sky
# 9        3.20     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_database/weatherpy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
